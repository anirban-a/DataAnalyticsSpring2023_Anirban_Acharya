# %%
library(ggplot2)
library(dplyr)

# %%
df <- read.csv('/content/2018_JP_VP_Level4.csv')

# %%
# see number of columns:
ncol(df)
nrow(df)
# Out:
# [1] 12
# [1] 221764

# %%
# see number of NA values.
sum(is.na(df))
# Out:
# [1] 478242

# %%
df <- na.omit(df)

# %%
ncol(df)
nrow(df)
# Out:
# [1] 12
# [1] 164646

# %%
# see number of NA values.
sum(is.na(df))
# Out:
# [1] 0

# %%
head(df)
# Out:
#     DateTime            Site_Name       Chla_Water_EXO SensorDepth_Water_EXO
# 675 2018-05-14 16:07:00 VP_AnthonysNose 0.198          0.99
# 676 2018-05-14 16:08:00 VP_AnthonysNose 0.099          1.80
# 677 2018-05-14 16:09:00 VP_AnthonysNose 0.072          3.04
# 678 2018-05-14 16:10:00 VP_AnthonysNose 0.180          3.83
# 680 2018-05-14 16:12:00 VP_AnthonysNose 0.324          4.83
# 681 2018-05-14 16:13:00 VP_AnthonysNose 0.279          5.91
#     DO_Water_EXO DO.Sat_Water_EXO SpCond_Water_EXO Temperature_Water_EXO
# 675 12.53        108.84           138.63           9.12
# 676 12.53        108.75           138.62           9.12
# 677 12.54        108.85           138.54           9.12
# 678 12.54        108.83           138.50           9.11
# 680 12.55        108.80           138.45           9.07
# 681 12.53        108.74           138.48           9.11
#     Turbidity_Water_EXO pH_Water_EXO PC_Water_EXO fDOM_Water_EXO
# 675 0.51                7.630000     0.1514716    1.030458
# 676 0.49                7.629989     0.1514716    1.066934
# 677 0.53                7.629978     0.1714021    1.021339
# 678 0.54                7.629967     0.1713567    1.057743
# 680 0.51                7.629945     0.1612234    1.020990
# 681 0.51                7.629934     0.1713567    1.066861

# %%
cols <- colnames(df)
cols
# Out:
#  [1] "DateTime"              "Site_Name"             "Chla_Water_EXO"
#  [4] "SensorDepth_Water_EXO" "DO_Water_EXO"          "DO.Sat_Water_EXO"
#  [7] "SpCond_Water_EXO"      "Temperature_Water_EXO" "Turbidity_Water_EXO"
# [10] "pH_Water_EXO"          "PC_Water_EXO"          "fDOM_Water_EXO"

# %% [markdown]
# ## Create a Dataframe of correlations between each numerical variables.

# %%
colx <- c()
coly <- c()
correlation <- c()

for(i in 3:(length(cols)-1)){
  for(j in (i+1):length(cols)){
    colx <- append(colx, cols[i])
    coly <- append(coly, cols[j])
    correlation <- append(correlation, cor(df[, i], df[, j]))
  }
}

correlations <- data.frame(colx, coly, correlation)

# %% [markdown]
# ### Let's look into the correlations:

# %%
correlations
# Out:
#    colx                  coly                  correlation
# 1  Chla_Water_EXO        SensorDepth_Water_EXO -2.172789e-01
# 2  Chla_Water_EXO        DO_Water_EXO           4.724719e-01
# 3  Chla_Water_EXO        DO.Sat_Water_EXO       3.465676e-01
# 4  Chla_Water_EXO        SpCond_Water_EXO       4.823578e-01
# 5  Chla_Water_EXO        Temperature_Water_EXO -1.768675e-01
# 6  Chla_Water_EXO        Turbidity_Water_EXO    5.446134e-01
# 7  Chla_Water_EXO        pH_Water_EXO           1.714259e-01
# 8  Chla_Water_EXO        PC_Water_EXO           2.780144e-01
# 9  Chla_Water_EXO        fDOM_Water_EXO         4.846406e-05
# 10 SensorDepth_Water_EXO DO_Water_EXO          -9.118491e-03
# 11 SensorDepth_Water_EXO DO.Sat_Water_EXO      -5.850034e-01
# 12 SensorDepth_Water_EXO SpCond_Water_EXO      -4.834565e-01
# 13 SensorDepth_Water_EXO Temperature_Water_EXO -7.565992e-01
# 14 SensorDepth_Water_EXO Turbidity_Water_EXO    8.049827e-02
# 15 SensorDepth_Water_EXO pH_Water_EXO          -7.773859e-01
# 16 SensorDepth_Water_EXO PC_Water_EXO           4.318840e-01
# 17 SensorDepth_Water_EXO fDOM_Water_EXO         6.225232e-01
# 18 DO_Water_EXO          DO.Sat_Water_EXO       7.219114e-01
# 19 DO_Water_EXO          SpCond_Water_EXO       1.599369e-01
# 20 DO_Water_EXO          Temperature_Water_EXO -3.840183e-01
# 21 DO_Water_EXO          Turbidity_Water_EXO    4.121852e-01
# 22 DO_Water_EXO          pH_Water_EXO           2.130319e-01
# 23 DO_Water_EXO          PC_Water_EXO           6.976152e-02
# 24 DO_Water_EXO          fDOM_Water_EXO        -8.965024e-02
# 25 DO.Sat_Water_EXO      SpCond_Water_EXO       3.551334e-01
# 26 DO.Sat_Water_EXO      Temperature_Water_EXO  3.561438e-01
# 27 DO.Sat_Water_EXO      Turbidity_Water_EXO    9.588756e-02
# 28 DO.Sat_Water_EXO      pH_Water_EXO           7.448735e-01
# 29 DO.Sat_Water_EXO      PC_Water_EXO          -3.586592e-01
# 30 DO.Sat_Water_EXO      fDOM_Water_EXO        -6.136288e-01
# 31 SpCond_Water_EXO      Temperature_Water_EXO  2.537725e-01
# 32 SpCond_Water_EXO      Turbidity_Water_EXO    5.429181e-01
# 33 SpCond_Water_EXO      pH_Water_EXO           2.496330e-01
# 34 SpCond_Water_EXO      PC_Water_EXO          -2.586286e-01
# 35 SpCond_Water_EXO      fDOM_Water_EXO        -3.955793e-01
# 36 Temperature_Water_EXO Turbidity_Water_EXO   -4.534524e-01
# 37 Temperature_Water_EXO pH_Water_EXO           6.991381e-01
# 38 Temperature_Water_EXO PC_Water_EXO          -5.866195e-01
# 39 Temperature_Water_EXO fDOM_Water_EXO        -7.076742e-01
# 40 Turbidity_Water_EXO   pH_Water_EXO          -2.648397e-01
# 41 Turbidity_Water_EXO   PC_Water_EXO           2.106438e-01
# 42 Turbidity_Water_EXO   fDOM_Water_EXO         2.416538e-01
# 43 pH_Water_EXO          PC_Water_EXO          -3.503074e-01
# 44 pH_Water_EXO          fDOM_Water_EXO        -7.955129e-01
# 45 PC_Water_EXO          fDOM_Water_EXO         5.038986e-01

# %% [markdown]
# ### Variables having positive correlations in descending order.

# %%
correlations |> filter(correlation>0)|>arrange(desc(correlation))
# Out:
#    colx                  coly                  correlation
# 1  SensorDepth_Water_EXO Temperature_Water_EXO 7.448735e-01
# 2  Chla_Water_EXO        SensorDepth_Water_EXO 7.219114e-01
# 3  DO.Sat_Water_EXO      Temperature_Water_EXO 6.991381e-01
# 4  Site_Name             pH_Water_EXO          6.225232e-01
# 5  DateTime              SpCond_Water_EXO      5.446134e-01
# 6  DO_Water_EXO          SpCond_Water_EXO      5.429181e-01
# 7  Turbidity_Water_EXO   pH_Water_EXO          5.038986e-01
# 8  DateTime              DO_Water_EXO          4.823578e-01
# 9  DateTime              Chla_Water_EXO        4.724719e-01
# 10 Site_Name             Turbidity_Water_EXO   4.318840e-01
# 11 Chla_Water_EXO        SpCond_Water_EXO      4.121852e-01
# 12 SensorDepth_Water_EXO DO.Sat_Water_EXO      3.561438e-01
# 13 SensorDepth_Water_EXO DO_Water_EXO          3.551334e-01
# 14 DateTime              SensorDepth_Water_EXO 3.465676e-01
# 15 DateTime              Turbidity_Water_EXO   2.780144e-01
# 16 DO_Water_EXO          DO.Sat_Water_EXO      2.537725e-01
# 17 DO_Water_EXO          Temperature_Water_EXO 2.496330e-01
# 18 SpCond_Water_EXO      pH_Water_EXO          2.416538e-01
# 19 Chla_Water_EXO        Temperature_Water_EXO 2.130319e-01
# 20 SpCond_Water_EXO      Turbidity_Water_EXO   2.106438e-01
# 21 DateTime              Temperature_Water_EXO 1.714259e-01
# 22 Chla_Water_EXO        DO_Water_EXO          1.599369e-01
# 23 SensorDepth_Water_EXO SpCond_Water_EXO      9.588756e-02
# 24 Site_Name             SpCond_Water_EXO      8.049827e-02
# 25 Chla_Water_EXO        Turbidity_Water_EXO   6.976152e-02
# 26 DateTime              pH_Water_EXO          4.846406e-05

# %%
# DO.Sat_Water_EXO vs pH_Water_EXO
ggplot(df, mapping=aes(x=DO.Sat_Water_EXO, y=pH_Water_EXO, color=as.factor(Site_Name)))+
  geom_point()
# Out:
# plot without title

# %%
# DO_Water_EXO vs	DO.Sat_Water_EXO
ggplot(df, aes(DO_Water_EXO,	DO.Sat_Water_EXO, color=as.factor(Site_Name)))+
  geom_point()
# Out:
# plot without title

# %%
# Temperature_Water_EXO	vs pH_Water_EXO
ggplot(df, aes(Temperature_Water_EXO,	pH_Water_EXO, color=as.factor(Site_Name)))+
  geom_point()
# Out:
# plot without title

# %% [markdown]
# ## Turbidity
#
# Turbidity is caused by particles suspended or dissolved in water that scatter light making the water appear cloudy or murky. Particulate matter can include sediment - especially clay and silt, fine **organic** and **inorganic** matter, soluble colored organic compounds, **algae**, and other microscopic organisms.

# %%
install.packages('hrbrthemes')
library(hrbrthemes)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘triebeard’, ‘httpuv’, ‘xtable’, ‘fontawesome’, ‘sourcetools’, ‘later’, ‘promises’, ‘urltools’, ‘httpcode’, ‘shiny’, ‘crul’, ‘fontBitstreamVera’, ‘fontLiberation’, ‘extrafontdb’, ‘Rttf2pt1’, ‘Rcpp’, ‘gfonts’, ‘fontquiver’, ‘extrafont’, ‘gdtools’
#
#
# Warning message in install.packages("hrbrthemes"):
# “installation of package ‘gdtools’ had non-zero exit status”
# Warning message in install.packages("hrbrthemes"):
# “installation of package ‘hrbrthemes’ had non-zero exit status”
# Error in library(hrbrthemes): there is no package called ‘hrbrthemes’
# Traceback:
#
# 1. library(hrbrthemes)

# %%
ggplot(df, aes(x=DateTime, y = Turbidity_Water_EXO))+
  geom_line()+
  theme_ipsum() +
  theme(axis.text.x=element_text(angle=60, hjust=1))
# Out:
# Error in theme_ipsum(): could not find function "theme_ipsum"
# Traceback:

# %%
str(df$DateTime)
